# %%
# %load_ext autoreload
# %autoreload 2
import robust_uncertainty

# %%
iter=1500
mu_d = 13.0
gan = 15.0
rho = 0.05
c_d = 1.
ponji = 1e-9
seed = 7

# %% [markdown]
# beta=0.95,theta=infty

# %%
beta = 0.95
sig = -1e-9

# %%
rolq = robust_uncertainty.mis(
    rho, mu_d, gan, c_d, sig, beta, ponji=ponji, iter=iter, seed=seed
)
rolq.mis_plot_time_series(d_plot=False, y_lim=True,size=False)
#rolq.nomis_plot_time_series(d_plot=False, y_lim=True,size=False)
print(rolq.get_Consumption_ave_std())
print(rolq.get_Saving_ave_std())
#_, _, _, c=rolq.state_transition()
##print(c[-1])
F, _, _, _=rolq.olrprobust()
print(F)
# Out:
# (10.839100714383724, 0.7780312501470971)
# (-41.03110168883272, 14.820301058954598)
# [[-2.68241495  0.05249346  0.0526316 ]]

# %% [markdown]
# beta=0.9447,theta=infty

# %%
beta = 0.9447644303007632
sig = -1e-9

# %%
rolq = robust_uncertainty.mis(
    rho, mu_d, gan, c_d, sig, beta, ponji=ponji, iter=iter, seed=seed
)
rolq.mis_plot_time_series(d_plot=False, y_lim=True,size=False)
print(rolq.get_Consumption_ave_std())
print(rolq.get_Saving_ave_std())
# Out:
# (10.613483013752937, 0.8592651053297164)
# (-40.7938136356159, 14.734597805148969)

# %% [markdown]
# beta=0.95,theta=10

# %%
beta = 0.95
sig = -1e-1

# %%
rolq = robust_uncertainty.mis(
    rho, mu_d, gan, c_d, sig, beta, ponji=ponji, iter=iter, seed=seed
)
rolq.mis_plot_time_series(d_plot=False, y_lim=True,size=False)
rolq.get_Consumption_ave_std()
# Out:
# (14.46495073047037, 0.7498689339237256)

# %% [markdown]
# beta=0.9447,theta=10

# %% [markdown]
# C:\Users\theko\Desktop\UEC\岩崎研\ミニプロジェクト_20230417\using_quant\sotsuken.ipynb
# を参照せよ

# %%
beta = 0.9447644303007632
sig = -1e-1

rolq = robust_uncertainty.mis(
    rho, mu_d, gan, c_d, sig, beta, ponji=ponji, iter=iter, seed=seed
)
F_obs, _, _, _=rolq.olrprobust()
print(F_obs)
rolq.mis_plot_time_series(d_plot=False, y_lim=True,size=False)
rolq.get_Consumption_ave_std()
# Out:
# [[-3.07355034  0.06470889  0.06525664]]
# (14.488622759382391, 0.7601566161663517)
